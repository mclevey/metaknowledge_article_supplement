# %% [markdown]
# ![](images/mk.png)
#
# <h1><center>ONLINE SUPPLEMENT</center></h1>
#
# John McLevey & Reid-McIlroy-Young. **Introducing *metaknowledge*: Software for Computational Research in Information Science, Science of Science, and Network Analysis.** *Journal of Informetrics*. 11:176-197.
#
# <h1><center>Part 1: Working With Record Collections</center></h1>
#
# These supplementary notebooks were prepared by Dr. [John McLevey](http://www.johnmclevey.com/) (University of Waterloo), [Reid McIlroy-Young](http://reidmcy.com/) (University of Chicago), and [Jillian Anderson](http://networkslab.org/) (NetLab, University of Waterloo).

# %% [markdown]
# # Getting Started

# %% [markdown]
# ### Installing Python, the Scientific Stack, and *metaknowledge*

# %% [markdown]
# This Github repository contains the data and executable code accompanying our article "Introducing metaknowledge: Software for Computational Research in Information Science, Science of Science, and Network Analysis."
#
# To use this Juputer Notebook:
#
# 1. Download or clone this [Github repository](https://github.com/mclevey/metaknowledge_article_supplement)
# 2. Download and install the [Anaconda distribution of Python3](https://www.continuum.io/downloads)
# 3. Download and install the current public releases of *metaknowledge*, *networkx*, and *NLTK* as described in the article text
# 4. From the same directory the Jupyter Notebook is in, type `jupyter notebook` on the command line

# %% [markdown]
# ### Load Packages

# %%
import metaknowledge as mk
import pandas

# for static graphs 
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
get_ipython().magic("config InlineBackend.figure_format = 'retina'")

sns.set_style(style="white") # change the default background plot colour
sns.set(font_scale=.75)
plt.rc("savefig", dpi=300) # improve default resolution of graphics

# for interactive graphs 
import plotly.plotly as py
import plotly.graph_objs as go
# if this is your first time using plot.ly, you will need to sign up
# for a free account and get an API key. details here: https://plot.ly/python/getting-started/
# alternatively, you can skip the plot.ly graphs use Seaborn to produce static graphs, or
# you could produce interactive graphs using another package, such as Bokeh.

# %% [markdown]
# The data files for our notebooks should be in a directory called `raw_data`.

# %% [markdown]
# # Creating and Processing Record Collections
#
# ### Parsing Raw Data to Create Records and RecordCollections

# %% [markdown]
# We have already set the working directory. All we need to do to create a `Record Collection` is provide the rest of the file path to the raw data. We will use the information science and bibliometrics dataset used in the "Introducing *metaknowledge*" article.

# %%
RC = mk.RecordCollection('raw_data/imetrics/', cached = True)
len(RC)
# Out:
# 8140

# %% [markdown]
# We can easily write the full dataframe to a `.csv` file using the `writeCSV` method. This file can, of course, be used by any other research software.

# %%
RC.writeCSV('generated_datasets/records.csv')

# %% [markdown]
# Of course it is also possible to continue working in Python. *metaknowledge* has some useful functions for working with `Record Collections`, but researchers can also use other Python packages such as *Pandas*.
#
# The code block below uses the *metaknowledge* method `yearSplit` to extract the records published in 2013 and 2014 and shows the estimates for author gender. The process for estimating author genders uses birth record and name data. It is described in the article.

# %%
RC1314 = RC.yearSplit(2013, 2014)
gender_breakdown = RC1314.genderStats()
gender_breakdown
# Out:
# {'Female': 506, 'Male': 1349, 'Unknown': 1361}

# %% [markdown]
# The `glimpse` method in *metaknowledge* is a convienent way to quickly view the most frequently occuring authors and journals, and the most highly cited articles. It will print a quick summary to screen.

# %%
print(RC.glimpse())
# Out:
# RecordCollection glimpse made at: 2017-08-29 09:36:01
# 8140 Records from files-from-raw_data/imetrics/
#
# Top Authors
# 1 Bornmann, Lutz
# 2 Leydesdorff, Loet
# 3 Thelwall, Mike
# 4 Rousseau, Ronald
# 5 SCHUBERT, A
# 6 D'Angelo, Ciriaco Andrea
# 6 Abramo, Giovanni
# 7 Glanzel, Wolfgang
# 8 Glanzel, W
# 9 Huang, Mu-Hsuan
# 10 BRAUN, T
# 10 Lariviere, Vincent
# 11 Waltman, Ludo
# 12 Ding, Ying
# 13 Daniel, Hans-Dieter
# 14 Cronin, Blaise
# 15 Rousseau, R
#
# Top Journals
# 1 SCIENTOMETRICS
# 2 JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATION SCIENCE AND TECHNOLOGY
# 3 JOURNAL OF INFORMETRICS
# 4 JOURNAL OF THE ASSOCIATION FOR INFORMATION SCIENCE AND TECHNOLOGY
#
# Top Cited
# 1 Hirsch JE, 2005, P NATL ACAD SCI USA, V102, P16569, DOI 10.1073/pnas.0507655102
# 2 Egghe L, 2006, SCIENTOMETRICS, V69, P131, DOI 10.1007/s11192-006-0144-7
# 3 SMALL H, 1973, J AM SOC INFORM SCI, V24, P265, DOI 10.1002/asi.4630240406
# 4 GARFIELD E, 1972, SCIENCE, V178, P471, DOI 10.1126/science.178.4060.471
# 5 MERTON RK, 1968, SCIENCE, V159, P56, DOI 10.1126/science.159.3810.56
# 5 Glanzel W, 2001, SCIENTOMETRICS, V51, P69, DOI 10.1023/A:1010512628145
# 6 Leydesdorff L, 2011, J AM SOC INF SCI TEC, V62, P846, DOI 10.1002/asi.21509
# 6 PRICE DJD, 1965, SCIENCE, V149, P510
# 7 Katz JS, 1997, RES POLICY, V26, P1, DOI 10.1016/S0048-7333(96)00917-1
# 8 Glanzel W, 2006, SCIENTOMETRICS, V67, P315, DOI 10.1556/Scient.67.2006.2.12
# 8 Wasserman S, 1994, SOCIAL NETWORK ANAL
# 9 Leydesdorff L, 2009, J AM SOC INF SCI TEC, V60, P348, DOI 10.1002/asi.20967
# 9 SCHUBERT A, 1986, SCIENTOMETRICS, V9, P281, DOI 10.1007/BF02017249
# 10 Moed H. F., 2005, CITATION ANAL RES EV
# 11 White HD, 1998, J AM SOC INFORM SCI, V49, P327, DOI 10.1002/(SICI)1097-4571(19980401)49:4<327::AID-ASI4>3.0.CO;2-W
# 11 De Solla Price Derek J., 1963, LITTLE SCI BIG SCI
# 12 Glanzel W, 2003, SCIENTOMETRICS, V56, P357, DOI 10.1023/A:1022378804087

# %% [markdown]
# While `glimpse` is useful for getting a quick sense of the most frequently appearing authors and journals, and the most highly cited documents, most research workflows require direct interaction with the data stored in the `Record Collection`. The easiest way to do this is to convert the `Record Collection` into a [Pandas](http://pandas.pydata.org/pandas-docs/stable/) dataframe. This provides access to a wide range of methods for selecting, filtering, grouping, summarizing, modeling, and plotting data.
#
# In addition to the *Pandas* documentation, researchers may want to consult Wes McKinney's book [*Python for Data Analysis: Data Wrangling with Pandas, NumPy, and IPython*](https://www.amazon.com/Python-Data-Analysis-Wrangling-IPython-ebook/dp/B009NLMB8Q) or an online tutorial (e.g. Julia Evans' [Pandas cookbook](https://jvns.ca/blog/2013/12/22/cooking-with-pandas/)).

# %%
df = pandas.DataFrame(RC.makeDict())
selectedVars = df[['AF', 'AB', 'PY', 'TI', 'SO', 'num-Authors', 'TC']]
selectedVars[:10] # show the first 10 rows.
# Out:
#                                                   AF  \
# 0  [Bordons, M, Zulueta, MA, Romero, F, Barrigon, S]
# 1                            [Yan, Erjia, Guns, Raf]
# 2                             [Davenport, Elisabeth]
# 3    [Schubert, Andras, Korn, Andras, Telcs, Andras]
# 4    [Liang, LM, Kretschmer, H, Guo, YZ, Beaver, DD]
# 5            [Gupta, BM, Kumar, S, Karisiddappa, CR]
# 6  [Espadas, Javier, Calero, Coral, Piattini, Mario]
# 7  [Yang, Guo-liang, Rousseau, Ronald, Yang, Li-y...
# 8                                         [Krull, W]
# 9  [Can, Fazli, Kocberber, Seyit, Baglioglu, Ozgu...
#
#                                                   AB    PY  \
# 0  A Multidisciplinary Research Programme (MRP) i...  1999
# 1  This study examines collaboration dynamics wit...  2014
# 2                                               None  2009
# 3  Hirsch-type indices are devised for characteri...  2009
# 4  This paper is a scientometric study of the age...  2001
# 5  Traces the growth of collaborated and funded r...  1997
# 6  In recent years, the Internet has experienced ...  2008
# 7  This paper investigates directional returns to...  2014
# 8                                               None  1999
# 9  Topic detection and tracking (TDT) application...  2010
#
#                                                   TI  \
# 0  Measuring interdisciplinary collaboration with...
# 1  Predicting and recommending collaborations: An...
# 2  Everyday Information Practices: A Social Pheno...
# 3    Hirsch-type indices for characterizing networks
# 4  Age structures of scientific collaboration in ...
# 5  Collaboration profile of theoretical populatio...
# 6                     Web site visibility evaluation
# 7            A study on directional returns to scale
# 8  Challenges to output measurement in science an...
# 9  New Event Detection and Topic Tracking in Turkish
#
#                                                   SO  num-Authors  TC
# 0                                     SCIENTOMETRICS            4  26
# 1                            JOURNAL OF INFORMETRICS            2   7
# 2  JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATIO...            1   1
# 3                                     SCIENTOMETRICS            3  19
# 4                                     SCIENTOMETRICS            4  20
# 5                                     SCIENTOMETRICS            3   9
# 6  JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATIO...            3  12
# 7                            JOURNAL OF INFORMETRICS            4   2
# 8                                     SCIENTOMETRICS            1   0
# 9  JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATIO...            6  10

# %% [markdown]
# The two letter variable names are the tags used by Web of Science. A description of the content of each tag is available [online](https://images.webofknowledge.com/images/help/WOS/h_fieldtags.html). The code block above shows 7 tags that are typically of interest, but there are many others available.

# %%
df.columns.values.tolist()
# Out:
# ['AB',
#  'AF',
#  'AU',
#  'BP',
#  'C1',
#  'CA',
#  'CL',
#  'CR',
#  'CT',
#  'CY',
#  'DE',
#  'DI',
#  'DT',
#  'EI',
#  'EM',
#  'EP',
#  'FU',
#  'FX',
#  'GA',
#  'HO',
#  'ID',
#  'IS',
#  'J9',
#  'JI',
#  'LA',
#  'NR',
#  'OI',
#  'PA',
#  'PD',
#  'PG',
#  'PI',
#  'PM',
#  'PT',
#  'PU',
#  'PY',
#  'RI',
#  'RP',
#  'SC',
#  'SI',
#  'SN',
#  'SO',
#  'SP',
#  'TC',
#  'TI',
#  'U1',
#  'U2',
#  'UT',
#  'VL',
#  'WC',
#  'Z9',
#  'num-Authors',
#  'num-Female',
#  'num-Male',
#  'num-Unknown']

# %% [markdown]
# We can sort these dataframe by any quantitative variable. Below, we show the 40 most highly cited articles in the dataset. Changing or removing the `[:40]` affects the number of records shown.

# %%
top_40 = selectedVars.sort_values(['TC'], ascending = False)[:40]
top_40
# Out:
#                                                      AF  \
# 5760                                       [Egghe, Leo]
# 7462                                           [Ho, YS]
# 3788              [Liben-Nowell, David, Kleinberg, Jon]
# 1348  [Spink, A, Wolfram, D, Jansen, MBJ, Saracevic, T]
# 3088                     [Meho, Lokman I., Yang, Kiduk]
# 1782  [Jansen, Bernard J., Zhang, Mimi, Sobel, Kate,...
# 2654                                         [Chen, CM]
# 7520                [Boyack, KW, Klavans, R, Borner, K]
# 5830                                    [Van Raan, AFJ]
# 3010            [MOED, HF, DEBRUIN, RE, VANLEEUWEN, TN]
# 7975                                      [GARFIELD, E]
# 6013                                    [Van Raan, AFJ]
# 3382                                       [Glanzel, W]
# 2933                            [SCHUBERT, A, BRAUN, T]
# 3841  [Braun, Tibor, Glanzel, Wolfgang, Schubert, An...
# 3175                             [Melin, G, Persson, O]
# 86                                           [Rieh, SY]
# 3503                             [Jansen, BJ, Pooch, U]
# 2826  [Batista, Pablo D., Campiteli, Monica G., Kino...
# 4416                                     [Nederhof, AJ]
# 2799                                        [PAVITT, K]
# 761                              [Glanzel, W, Moed, HF]
# 6141                   [MacRoberts, MH, MacRoberts, BR]
# 4028            [Ahlgren, P, Jarneving, B, Rousseau, R]
# 5315                [Leydesdorff, Loet, Rafols, Ismael]
# 2610                [NARIN, F, STEVENS, K, WHITLOW, ES]
# 2095                                  [Bar-Ilan, Judit]
# 3176                [SCHUBERT, A, GLANZEL, W, BRAUN, T]
# 7090              [CALLON, M, COURTIAL, JP, LAVILLE, F]
# 5308                           [Wathen, CN, Burkell, J]
# 1899  [Alonso, S., Cabrerizo, F. J., Herrera-Viedma,...
# 155                                          [KATZ, JS]
# 5123  [Thelwall, Mike, Buckley, Kevan, Paltoglou, Ge...
# 1814              [Bornmann, Lutz, Daniel, Hans-Dieter]
# 7246                                     [vanRaan, AFJ]
# 900   [Bollen, Johan, Rodriguez, Marko A., Van de So...
# 7436  [Bornmann, Lutz, Mutz, Ruediger, Daniel, Hans-...
# 7031                                    [Moed, Henk F.]
# 1014                [Persson, O, Glanzel, W, Danell, R]
# 3472                               [Metzger, Miriam J.]
#
#                                                      AB    PY  \
# 5760  The g-index is introduced as an improvement of...  2006
# 7462  This study presents a literature review concer...  2004
# 3788  Given a snapshot of a social network, can we i...  2007
# 1348  In studying actual Web searching by the public...  2001
# 3088  The Institute for Scientific Information's (IS...  2007
# 1782  In this paper we report research results inves...  2009
# 2654  This article describes the latest development ...  2006
# 7520  This paper presents a new map representing the...  2005
# 5830  In this paper we present characteristics of th...  2006
# 3010  This paper gives an outline of a new bibliomet...  1995
# 7975                                               None  1979
# 6013  Ranking of research institutions by bibliometr...  2005
# 3382  The main objective of this study is the elabor...  2001
# 2933                                               None  1986
# 3841  We suggest that a h-type index - equal to h if...  2006
# 3175  Scientific collaboration has become a major is...  1996
# 86    In the Web, making judgments of information qu...  2002
# 3503  Research on Web searching is at an incipient s...  2001
# 2826  The number h of papers with at least h citatio...  2006
# 4416  This paper addresses research performance moni...  2006
# 2799                                               None  1985
# 761   The Impact Factor introduced by Eugene Garfiel...  2002
# 6141                                               None  1996
# 4028  Author cocitation analysis (ACA), a special ty...  2003
# 5315  The decomposition of scientific literature int...  2009
# 2610  Under the sponsorship of the U.S. National Sci...  1991
# 2095  This paper compares the h-indices of a list of...  2008
# 3176                                               None  1989
# 7090  The goal of this paper is to show how co-word ...  1991
# 5308  This article reviews selected literature relat...  2002
# 1899  The h-index and some related bibliometric indi...  2009
# 155   Geography, economic, socio-political and langu...  1994
# 5123  A huge number of informal messages are posted ...  2010
# 1814  Jorge Hirsch (2005a, 2005b) recently proposed ...  2007
# 7246  This paper gives an overview of the potentials...  1996
# 900   The status of an actor in a social context is ...  2006
# 7436  In this study, we examined empirical results o...  2008
# 7031  This paper explores a new indicator of journal...  2010
# 1014  Several research studies and reports on nation...  2004
# 3472  This article summarizes much of what is known ...  2007
#
#                                                      TI  \
# 5760                 Theory and practise of the g-index
# 7462  Citation review of Lagergren kinetic rate equa...
# 3788    The link-prediction problem for social networks
# 1348    Searching the Web: The public and their queries
# 3088  Impact of data sources on citation counts and ...
# 1782  Twitter Power: Tweets as Electronic Word of Mouth
# 2654  CiteSpace II: Detecting and visualizing emergi...
# 7520                    Mapping the backbone of science
# 5830  Comparison of the Hirsch-index with standard b...
# 3010  NEW BIBLIOMETRIC TOOLS FOR THE ASSESSMENT OF N...
# 7975  IS CITATION ANALYSIS A LEGITIMATE EVALUATION TOOL
# 6013  Fatal attraction: Conceptual and methodologica...
# 3382  National characteristics in international scie...
# 2933  RELATIVE INDICATORS AND RELATIONAL CHARTS FOR ...
# 3841                   A Hirsch-type index for journals
# 3175  Studying research collaboration using co-autho...
# 86    Judgment of information quality and cognitive ...
# 3503  A review of Web searching studies and a framew...
# 2826  Is it possible to compare researchers with dif...
# 4416  Bibliometric monitoring of research performanc...
# 2799  PATENT STATISTICS AS INDICATORS OF INNOVATIVE ...
# 761    Journal impact measures in bibliometric research
# 6141                      Problems of citation analysis
# 4028  Requirements for a cocitation similarity measu...
# 5315  A Global Map of Science Based on the ISI Subje...
# 2610  SCIENTIFIC COOPERATION IN EUROPE AND THE CITAT...
# 2095  Which h-index? - A comparison of WoS, Scopus a...
# 3176  SCIENTOMETRIC DATAFILES - A COMPREHENSIVE SET ...
# 7090  CO-WORD ANALYSIS AS A TOOL FOR DESCRIBING THE ...
# 5308  Believe it or not: Factors influencing credibi...
# 1899  h-Index: A review focused in its variants, com...
# 155   GEOGRAPHICAL PROXIMITY AND SCIENTIFIC COLLABOR...
# 5123  Sentiment in Short Strength Detection Informal...
# 1814                 What do we know about the h index?
# 7246  Advanced bibliometric methods as quantitative ...
# 900                                      Journal status
# 7436  Are there better indices for evaluation purpos...
# 7031  Measuring contextual citation impact of scient...
# 1014  Inflationary bibliometric values: The role of ...
# 3472  Making sense of credibility on the web: Models...
#
#                                                      SO  num-Authors   TC
# 5760                                     SCIENTOMETRICS            1  538
# 7462                                     SCIENTOMETRICS            1  527
# 3788  JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATIO...            2  437
# 1348  JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATIO...            4  365
# 3088  JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATIO...            2  315
# 1782  JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATIO...            4  308
# 2654  JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATIO...            1  293
# 7520                                     SCIENTOMETRICS            3  288
# 5830                                     SCIENTOMETRICS            1  262
# 3010                                     SCIENTOMETRICS            3  259
# 7975                                     SCIENTOMETRICS            1  255
# 6013                                     SCIENTOMETRICS            1  249
# 3382                                     SCIENTOMETRICS            1  242
# 2933                                     SCIENTOMETRICS            2  231
# 3841                                     SCIENTOMETRICS            3  225
# 3175                                     SCIENTOMETRICS            2  207
# 86    JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATIO...            1  206
# 3503  JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATIO...            2  204
# 2826                                     SCIENTOMETRICS            4  203
# 4416                                     SCIENTOMETRICS            1  203
# 2799                                     SCIENTOMETRICS            1  202
# 761                                      SCIENTOMETRICS            2  198
# 6141                                     SCIENTOMETRICS            2  197
# 4028  JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATIO...            3  195
# 5315  JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATIO...            2  194
# 2610                                     SCIENTOMETRICS            3  192
# 2095                                     SCIENTOMETRICS            1  189
# 3176                                     SCIENTOMETRICS            3  188
# 7090                                     SCIENTOMETRICS            3  185
# 5308  JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATIO...            2  184
# 1899                            JOURNAL OF INFORMETRICS            4  174
# 155                                      SCIENTOMETRICS            1  172
# 5123  JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATIO...            5  172
# 1814  JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATIO...            2  170
# 7246                                     SCIENTOMETRICS            1  170
# 900                                      SCIENTOMETRICS            3  167
# 7436  JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATIO...            3  166
# 7031                            JOURNAL OF INFORMETRICS            1  166
# 1014                                     SCIENTOMETRICS            3  166
# 3472  JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATIO...            1  165

# %% [markdown]
# We will create a new column called `short_title` that will contain the first 20 characters in the title. We can then use this new variable to create a horizontal bar graph with reasonable labels on the y-axis. (If we did not shorten them, the y-axis label would be as wide as the longest article title.)

# %%
top_40['short_title'] = top_40['TI'].str[:20]
top_40[['TI', 'short_title', 'TC']]
# Out:
#                                                      TI           short_title  \
# 5760                 Theory and practise of the g-index  Theory and practise
# 7462  Citation review of Lagergren kinetic rate equa...  Citation review of L
# 3788    The link-prediction problem for social networks  The link-prediction
# 1348    Searching the Web: The public and their queries  Searching the Web: T
# 3088  Impact of data sources on citation counts and ...  Impact of data sourc
# 1782  Twitter Power: Tweets as Electronic Word of Mouth  Twitter Power: Tweet
# 2654  CiteSpace II: Detecting and visualizing emergi...  CiteSpace II: Detect
# 7520                    Mapping the backbone of science  Mapping the backbone
# 5830  Comparison of the Hirsch-index with standard b...  Comparison of the Hi
# 3010  NEW BIBLIOMETRIC TOOLS FOR THE ASSESSMENT OF N...  NEW BIBLIOMETRIC TOO
# 7975  IS CITATION ANALYSIS A LEGITIMATE EVALUATION TOOL  IS CITATION ANALYSIS
# 6013  Fatal attraction: Conceptual and methodologica...  Fatal attraction: Co
# 3382  National characteristics in international scie...  National characteris
# 2933  RELATIVE INDICATORS AND RELATIONAL CHARTS FOR ...  RELATIVE INDICATORS
# 3841                   A Hirsch-type index for journals  A Hirsch-type index
# 3175  Studying research collaboration using co-autho...  Studying research co
# 86    Judgment of information quality and cognitive ...  Judgment of informat
# 3503  A review of Web searching studies and a framew...  A review of Web sear
# 2826  Is it possible to compare researchers with dif...  Is it possible to co
# 4416  Bibliometric monitoring of research performanc...  Bibliometric monitor
# 2799  PATENT STATISTICS AS INDICATORS OF INNOVATIVE ...  PATENT STATISTICS AS
# 761    Journal impact measures in bibliometric research  Journal impact measu
# 6141                      Problems of citation analysis  Problems of citation
# 4028  Requirements for a cocitation similarity measu...  Requirements for a c
# 5315  A Global Map of Science Based on the ISI Subje...  A Global Map of Scie
# 2610  SCIENTIFIC COOPERATION IN EUROPE AND THE CITAT...  SCIENTIFIC COOPERATI
# 2095  Which h-index? - A comparison of WoS, Scopus a...  Which h-index? - A c
# 3176  SCIENTOMETRIC DATAFILES - A COMPREHENSIVE SET ...  SCIENTOMETRIC DATAFI
# 7090  CO-WORD ANALYSIS AS A TOOL FOR DESCRIBING THE ...  CO-WORD ANALYSIS AS
# 5308  Believe it or not: Factors influencing credibi...  Believe it or not: F
# 1899  h-Index: A review focused in its variants, com...  h-Index: A review fo
# 155   GEOGRAPHICAL PROXIMITY AND SCIENTIFIC COLLABOR...  GEOGRAPHICAL PROXIMI
# 5123  Sentiment in Short Strength Detection Informal...  Sentiment in Short S
# 1814                 What do we know about the h index?  What do we know abou
# 7246  Advanced bibliometric methods as quantitative ...  Advanced bibliometri
# 900                                      Journal status        Journal status
# 7436  Are there better indices for evaluation purpos...  Are there better ind
# 7031  Measuring contextual citation impact of scient...  Measuring contextual
# 1014  Inflationary bibliometric values: The role of ...  Inflationary bibliom
# 3472  Making sense of credibility on the web: Models...  Making sense of cred
#
#        TC
# 5760  538
# 7462  527
# 3788  437
# 1348  365
# 3088  315
# 1782  308
# 2654  293
# 7520  288
# 5830  262
# 3010  259
# 7975  255
# 6013  249
# 3382  242
# 2933  231
# 3841  225
# 3175  207
# 86    206
# 3503  204
# 2826  203
# 4416  203
# 2799  202
# 761   198
# 6141  197
# 4028  195
# 5315  194
# 2610  192
# 2095  189
# 3176  188
# 7090  185
# 5308  184
# 1899  174
# 155   172
# 5123  172
# 1814  170
# 7246  170
# 900   167
# 7436  166
# 7031  166
# 1014  166
# 3472  165

# %%
with sns.axes_style("white"):
    horizontal_bar = sns.barplot(data = top_40, x = 'TC', y = 'short_title', color = 'gray')
    horizontal_bar.set(xlabel='Number of Citations', ylabel='')
    sns.despine(left = True, right = True, bottom = True, top = True)
    plt.tight_layout()
plt.savefig('figures/horizontal_barplot.pdf') # margins need adjustment

# %% [markdown]
# Creating Time Series Datasets
# -----------------------------

# %% [markdown]
# It is also easy to plot time series graphs, for example of article publications over time. We can do this by use the `timeSeries` method in *metaknowledge*, and converting the results into a *Pandas* dataframe that can be easily plotted. We will write the time series dataset to a `csv` file at the same time.

# %%
#[2:] removes incomplete data from 2016
growth = pandas.DataFrame(RC.timeSeries('year', outputFile = 'generated_datasets/growth.csv'))[2:]
growth[:10]
# Out:
#     count  entry  year
# 2     643   2014  2014
# 3     572   2013  2013
# 4     545   2012  2012
# 5     494   2011  2011
# 6     535   2010  2010
# 7     467   2009  2009
# 8     389   2008  2008
# 9     395   2007  2007
# 10    353   2006  2006
# 11    267   2005  2005

# %%
with sns.axes_style("white"):
    plt.plot(growth['year'], growth['count'], color = 'gray')
    sns.despine() # improve the look of the plot
    plt.tight_layout() # decrease white space around margins
plt.savefig("figures/growth_chart.pdf")

# %% [markdown]
# Static graphs are necessary for journal article plublications, packages like [Seaborn](https://seaborn.pydata.org) make it easy to produce publication quality graphs. One of the advantages of working in a Jupyter Notebook, however, is that we can use libraries like [Bokeh](http://bokeh.pydata.org) and [plot.ly](https://plot.ly/python/) to produce interactive graphs. These are especially helpful for exploratoring data.
#
# Let's produce the same line graph again, this time with plot.ly. Tip: hover over the points on the graph.

# %%
trace = go.Scatter(
    x = growth['year'],
    y = growth['count'],
    mode = 'lines+markers',
    name = 'lines+markers'
)

data = [trace]

py.iplot(data, filename='growth-over-time')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mclevey/2.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# We can also plot a subset of the data. Below, we extract the data for *Scientometrics* and *The Journal of Informetrics* and plot them side by side.

# %%
subset = ['SCIENTOMETRICS', 'JOURNAL OF INFORMETRICS']
growth_by_journal = pandas.DataFrame(RC.timeSeries('journal', 
    outputFile = 'generated_datasets/growth_journals.csv', limitTo = subset))
growth_by_journal[:10]
# Out:
#    count                    entry  year
# 0    143           SCIENTOMETRICS  2016
# 1     59  JOURNAL OF INFORMETRICS  2016
# 2    343           SCIENTOMETRICS  2015
# 3     84  JOURNAL OF INFORMETRICS  2015
# 4    338           SCIENTOMETRICS  2014
# 5     90  JOURNAL OF INFORMETRICS  2014
# 6    249           SCIENTOMETRICS  2013
# 7    103  JOURNAL OF INFORMETRICS  2013
# 8    252           SCIENTOMETRICS  2012
# 9     78  JOURNAL OF INFORMETRICS  2012

# %%
with sns.axes_style("white"):
    fig, ax = plt.subplots()
    growth_by_scientometrics = growth_by_journal[growth_by_journal['entry'] == 'SCIENTOMETRICS'][::-1]
    growth_by_informetrics = growth_by_journal[growth_by_journal['entry'] == 'JOURNAL OF INFORMETRICS'][::-1]
    growth_by_scientometrics.plot(ax = ax, y ='count', x = 'year', label = 'SCIENTOMETRICS')
    growth_by_informetrics.plot(ax = ax, y ='count', x = 'year', label = 'JOURNAL OF INFORMETRICS')
    sns.despine()
plt.savefig('figures/growth_compare.pdf')

# %% [markdown]
# Here's the interactive version with plot.ly. This time we will exclude 2016 data because our dataset does not include the full year.

# %%
growth_by_journal2 = pandas.DataFrame(RC.timeSeries('journal', outputFile = 'generated_datasets/growth_journals.csv'))
growth_by_journal2.head()
# Out:
#    count                                              entry  year
# 0    143                                     SCIENTOMETRICS  2016
# 1    115  JOURNAL OF THE ASSOCIATION FOR INFORMATION SCI...  2016
# 2     59                            JOURNAL OF INFORMETRICS  2016
# 3    343                                     SCIENTOMETRICS  2015
# 4    216  JOURNAL OF THE ASSOCIATION FOR INFORMATION SCI...  2015

# %%
scientometrics = growth_by_journal2[(growth_by_journal2.entry == 'SCIENTOMETRICS') & (growth_by_journal2.year <= 2015)]
informetrics = growth_by_journal2[(growth_by_journal2.entry == 'JOURNAL OF INFORMETRICS') & (growth_by_journal2.year <= 2015)]
jaist = growth_by_journal2[(growth_by_journal2.entry == 'JOURNAL OF THE ASSOCIATION FOR INFORMATION SCIENCE AND TECHNOLOGY') & (growth_by_journal2.year <= 2015)]
jasist = growth_by_journal2[(growth_by_journal2.entry == 'JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATION SCIENCE AND TECHNOLOGY') & (growth_by_journal2.year <= 2015)]

# %%
trace1 = go.Scatter(
    x = scientometrics['year'],
    y = scientometrics['count'],
    mode = 'lines+markers',
    name = 'Scientometrics'
)
trace2 = go.Scatter(
    x = informetrics['year'],
    y = informetrics['count'],
    mode = 'lines+markers',
    name = 'Journal of Informetrics'
)
trace3 = go.Scatter(
    x = jaist['year'],
    y = jaist['count'],
    mode = 'lines+markers',
    name = 'JAIST (New Name)'
)
trace4 = go.Scatter(
    x = jasist['year'],
    y = jasist['count'],
    mode = 'lines+markers',
    name = 'JASIST (Old Name)'
)

data = [trace1, trace2, trace3, trace4]

py.iplot(data, filename='growth-over-time')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mclevey/2.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# Although the first issue of JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATION SCIENCE AND TECHNOLOGY came out in 1950, the Web of Science does not have meta-data on the journal before 2001.

# %% [markdown]
# Other methods for working with `Record Collections` (e.g. for RPYS analysis, text analysis, and network analysis) are provided in the other supplementary Jupyter Notebooks.
